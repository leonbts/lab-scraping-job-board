# %% [markdown]
# # Job Board Scraping Lab
#
# In this lab you will first see a minimal but fully functional code snippet to scrape the LinkedIn Job Search webpage. You will then work on top of the example code and complete several chanllenges.
#
# ### Some Resources
#
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %%
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?currentJobId=4187409133&'
    
    # Assemble the full url with parameters
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])

    # Create a request to get the data from the server 
    page = requests.get(scrape_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    results = soup.select('ul.jobs-search__results-list')[0] # get list with cards
    cards = results.select("div.base-search-card__info") # get each card individualls
    for card in cards:
        title = card.find("h3", class_="base-search-card__title").get_text(strip=True)
        company = card.find("h4", class_="base-search-card__subtitle").get_text(strip=True)
        location = card.find("span", class_="job-search-card__location").get_text(strip=True)
        titles.append(title)
        companies.append(company)
        locations.append(location)
    data = pd.DataFrame({
        "title":titles,
        "company":companies,
        "location":locations
    })
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search('data%20analysis')
results
# Out:
#                                                 title  \
# 0                                        Data Analyst
# 1                                    Business Analyst
# 2                                    Business Analyst
# 3                       Business Intelligence Analyst
# 4   Business Intelligence Analyst, Growth Marketin...
# 5                         Analyst, Business Analytics
# 6                                    Business Analyst
# 7                                    Business Analyst
# 8   Business Intelligence Analyst, Growth Marketin...
# 9   Portfolio Management Analyst - Crystal Creek C...
# 10  Analyst/Sr Analyst, Revenue Management Market ...
# 11                                       Data Analyst
# 12                      Business Intelligence Analyst
# 13                                   Business Analyst
# 14                         Analyst, Business Strategy
# 15                           Data & Analytics Analyst
# 16                                       Data Analyst
# 17                                       Data Analyst
# 18                           Junior Financial Analyst
# 19       Business Analyst � Data Analytics & Strategy
# 20                                       Data Analyst
# 21                                Junior Data Analyst
# 22                                Junior Data Analyst
# 23                             Sr. Manager, Analytics
# 24               Data Analyst – Power Market Modeling
# 25                                  Analyst-Marketing
# 26               Senior Analyst - Strategy Consulting
# 27                       Performance Insights Manager
# 28                       Performance Insights Manager
# 29  Senior Data Analyst, GTM Operations and Analyt...
# 30  Data Analyst, Pharma, Health and Wellness Medi...
# 31                                 L/S Equity Analyst
# 32             Senior Manager, Analytics and Insights
# 33               Data Analyst (Business Intelligence)
# 34                  Data Analyst, TOM Data Infra Team
# 35                                Data Analyst Intern
# 36                    Senior Analyst BI Data Analysis
# 37  Process Improvement and Business Intelligence ...
# 38                 SVB - Data Analyst, Sales Strategy
# 39                     Analyst, Performance Assurance
# 40                                            Analyst
# 41                                       Data Analyst
# 42                               Quantitative Analyst
# 43                  Data Analyst - Data Research Team
# 44                                       Data Analyst
# 45                                       Data Analyst
# 46                              Research Data Analyst
# 47                                       Data Analyst
# 48                                  Senior Strategist
# 49                                       Data Analyst
# 50                                       Data Analyst
# 51                                 Jr. ArcGIS Analyst
# 52                                       Data Analyst
# 53                        Analytics Engineer (Hybrid)
# 54                           Data and Process Analyst
# 55                                       DATA ANALYST
# 56                                       Data Analyst
# 57              Business Analytics Specialist, Hybrid
# 58            Growth Strategy & Analytics Coordinator
# 59             Data Analytics & Visualization Analyst
#
#                                   company                       location
# 0                 The Walt Disney Company                   New York, NY
# 1                                   Foley           Texas, United States
# 2                                   Foley  South Carolina, United States
# 3                                 Staples                 Framingham, MA
# 4                                  Google                  Sunnyvale, CA
# 5                                   Petco                     Austin, TX
# 6                                   Foley         Florida, United States
# 7                                   Foley         Georgia, United States
# 8                                  Google              San Francisco, CA
# 9                        The Yarrow Group                    Jackson, WY
# 10                      American Airlines                     Dallas, TX
# 11                                 Stripe                    Seattle, WA
# 12                              Tripalink                  Charlotte, NC
# 13                                  Foley                   Hartford, CT
# 14                The Walt Disney Company                    Burbank, CA
# 15                      L.E.K. Consulting                     Boston, NY
# 16                 SWK Technologies, Inc.                  United States
# 17                                  Thryv                  United States
# 18                Blackstone Talent Group         San Francisco Bay Area
# 19                                KAPITAL                  United States
# 20                               AARATECH      California, United States
# 21                               AARATECH        New York, United States
# 22                           TalentBridge                  Charlotte, NC
# 23                 Haus Labs By Lady Gaga                 El Segundo, CA
# 24                       174 Power Global                     Irvine, CA
# 25                       American Express                   New York, NY
# 26                        Red Chalk Group                    Chicago, IL
# 27                                   Etsy                   Brooklyn, NY
# 28                                   Etsy                   Brooklyn, NY
# 29                     Palo Alto Networks                Santa Clara, CA
# 30                                 M3 USA            Fort Washington, PA
# 31                         Selby Jennings                   New York, NY
# 32                              Talkiatry                   New York, NY
# 33                                    ZBD                  United States
# 34                                 Amazon                   Bellevue, WA
# 35                                  Lensa                    Buffalo, NY
# 36                                 Nestlé                  Arlington, VA
# 37                             LP Analyst                     Dallas, TX
# 38                    Silicon Valley Bank                     Austin, TX
# 39                      American Airlines                     Dallas, TX
# 40                       MidCap Financial                   Bethesda, MD
# 41                                  Lensa                   New York, NY
# 42                             Kforce Inc                     Boston, MA
# 43                              The Block                  United States
# 44                                 Xactus    Pennsylvania, United States
# 45                                  Lensa                  United States
# 46        Indiana University Indianapolis               Indianapolis, IN
# 47                             Kforce Inc              North Reading, MA
# 48                             DTE Energy                    Detroit, MI
# 49                             Kforce Inc                     Warren, MI
# 50                                 Inceed                    Catoosa, OK
# 51          Sligo Software Solutions Inc.                   New York, NY
# 52              Chicago Housing Authority                    Chicago, IL
# 53                               Weedmaps                     Austin, TX
# 54                            PharmaForce                  United States
# 55                                  Lensa                   New York, NY
# 56                   City of Philadelphia               Philadelphia, PA
# 57  University of Maryland Medical System                  Baltimore, MD
# 58                          Privia Health                  Arlington, VA
# 59                                  Lensa                  Charlotte, NC

# %% [markdown]
# ## Challenge 1
#
# The first challenge for you is to update the `scrape_linkedin_job_search` function by adding a new parameter called `num_pages`. This will allow you to search more than 25 jobs with this function. Suggested steps:
#
# 1. Go to https://www.linkedin.com/jobs/search/?keywords=data%20analysis in your browser.
# 1. Scroll down the left panel and click the page 2 link. Look at how the URL changes and identify the page offset parameter.
# 1. Add `num_pages` as a new param to the `scrape_linkedin_job_search` function. Update the function code so that it uses a "for" loop to retrieve several pages of search results.
# 1. Test your new function by scraping 5 pages of the search results.
#
# Hint: Prepare for the case where there are less than 5 pages of search results. Your function should be robust enough to **not** trigger errors. Simply skip making additional searches and return all results if the search already reaches the end.

# %%
"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, pages):
    
    listing_count = 0
    titles = []
    companies = []
    locations = []
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?currentJobId=4187409133&'

    for _ in range(pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&start=', str(listing_count)])
        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

        results = soup.select('ul.jobs-search__results-list')[0] # get list with cards
        cards = results.select("div.base-search-card__info") # get each card individualls
        for card in cards:
            title = card.find("h3", class_="base-search-card__title").get_text(strip=True)
            company = card.find("h4", class_="base-search-card__subtitle").get_text(strip=True)
            location = card.find("span", class_="job-search-card__location").get_text(strip=True)
            titles.append(title)
            companies.append(company)
            locations.append(location)
            listing_count += 1
    data = pd.DataFrame({
        "title":titles,
        "company":companies,
        "location":locations
    })
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search_pages('data%20analysis', 5)
results
# Out:
#                                                  title  \
# 0                                         Data Analyst
# 1                                     Business Analyst
# 2                                     Business Analyst
# 3                        Business Intelligence Analyst
# 4    Business Intelligence Analyst, Growth Marketin...
# ..                                                 ...
# 295                        Analytics Engineer (Hybrid)
# 296                           Data and Process Analyst
# 297                                       DATA ANALYST
# 298            Growth Strategy & Analytics Coordinator
# 299                      Business Intelligence Analyst
#
#                      company                       location
# 0    The Walt Disney Company                   New York, NY
# 1                      Foley           Texas, United States
# 2                      Foley  South Carolina, United States
# 3                    Staples                 Framingham, MA
# 4                     Google                  Sunnyvale, CA
# ..                       ...                            ...
# 295                 Weedmaps                     Austin, TX
# 296              PharmaForce                  United States
# 297                    Lensa                   New York, NY
# 298            Privia Health                  Arlington, VA
# 299              Onora Group                  Nashville, TN
#
# [300 rows x 3 columns]

# %% [markdown]
# ## Challenge 2
#
# Further improve your function so that it can search jobs in a specific country. Add the 3rd param to your function called `country`. The steps are identical to those in Challange 1.

# %%
"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages_countries(keywords, pages, country):
    
    listing_count = 0
    titles = []
    companies = []
    locations = []
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?currentJobId=4187409133&'

    for _ in range(pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&location=', country, '&start=', str(listing_count)])
        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

        results = soup.select('ul.jobs-search__results-list')[0] # get list with cards
        cards = results.select("div.base-search-card__info") # get each card individualls
        for card in cards:
            title = card.find("h3", class_="base-search-card__title").get_text(strip=True)
            company = card.find("h4", class_="base-search-card__subtitle").get_text(strip=True)
            location = card.find("span", class_="job-search-card__location").get_text(strip=True)
            titles.append(title)
            companies.append(company)
            locations.append(location)
            listing_count += 1
    data = pd.DataFrame({
        "title":titles,
        "company":companies,
        "location":locations
    })
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search_pages_countries('data%20analysis', 5, 'Germany')
results
# Out:
#                                                  title            company  \
# 0                                       Data Scientist              Mondu
# 1                      Graduate Private Equity Analyst           CityGrad
# 2                  People Analytics Specialist (m/w/d)               ZARA
# 3                         Data Analytics Analyst (H/F)           ODDO BHF
# 4                                  Junior Data Analyst             AMBOSS
# ..                                                 ...                ...
# 295  Spezialist/in Statistik  (reine Statistik + SP...            WissPro
# 296       Junior Business Operations Associate (m/f/d)  Fusion Consulting
# 297                      Junior Data Scientist (m/w/d)    Lidl in Germany
# 298                  Power BI Business Analyst (m/w/d)  TALENTLOTSEN GmbH
# 299  Project Management Officer / Project Support (...          TieTalent
#
#                                     location
# 0                    Berlin, Berlin, Germany
# 1                   Munich, Bavaria, Germany
# 2                  Hamburg, Hamburg, Germany
# 3                  Frankfurt, Hesse, Germany
# 4                    Berlin, Berlin, Germany
# ..                                       ...
# 295                                  Germany
# 296     Mainz, Rhineland-Palatinate, Germany
# 297   Neckarsulm, Baden-Württemberg, Germany
# 298    Offenburg, Baden-Württemberg, Germany
# 299  Ludwigsburg, Baden-Württemberg, Germany
#
# [300 rows x 3 columns]

# %% [markdown]
# ## Challenge 3
#
# Add the 4th param called `num_days` to your function to allow it to search jobs posted in the past X days. Note that in the LinkedIn job search the searched timespan is specified with the following param:
#
# ```
# f_TPR=r259200
# ```
#
# The number part in the param value is the number of seconds. 259,200 seconds equal to 3 days. You need to convert `num_days` to number of seconds and supply that info to LinkedIn job search.

# %%
def scrape_linkedin_job_search_pages_countries_days(keywords, pages, country, num_days):
    """
    Searches LinkedIn jobs with specified keywords, country, and date range.
    
    Parameters:
    - keywords (str): URL-encoded job title or skill
    - pages (int): Number of result pages to scrape
    - country (str): Country name or region
    - num_days (int): Filter jobs posted in the last X days
    """
    listing_count = 0
    titles = []
    companies = []
    locations = []

    # Convert days to seconds and form the f_TPR param
    seconds = num_days * 86400
    time_filter = f"f_TPR=r{seconds}"

    BASE_URL = 'https://www.linkedin.com/jobs/search/?'

    for _ in range(pages):
        scrape_url = ''.join([
            BASE_URL,
            'keywords=', keywords,
            '&location=', country,
            '&', time_filter,
            '&start=', str(listing_count)
        ])
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

        try:
            results = soup.select('ul.jobs-search__results-list')[0]
        except IndexError:
            break  # no results found
        cards = results.select("div.base-search-card__info")
        for card in cards:
            title = card.find("h3", class_="base-search-card__title").get_text(strip=True)
            company = card.find("h4", class_="base-search-card__subtitle").get_text(strip=True)
            location = card.find("span", class_="job-search-card__location").get_text(strip=True)
            titles.append(title)
            companies.append(company)
            locations.append(location)
            listing_count += 1

    return pd.DataFrame({
        "title": titles,
        "company": companies,
        "location": locations
    })

# %%
results = scrape_linkedin_job_search_pages_countries_days('data%20analysis', 3, 'Canada', 5)
results
# Out:
#                                                  title  \
# 0                               Data Analyst - Banking
# 1                             Business Systems Analyst
# 2                            Decision Sciences Analyst
# 3                                       Data Scientist
# 4                                     Business Analyst
# ..                                                 ...
# 175                                            Data BA
# 176                         Technical Business Analyst
# 177      Investment Banking Analyst, Co-op Winter 2026
# 178  Business Intelligence Engineer, P2 Science, Da...
# 179                         Data Scientist, Amazon Ads
#
#                                   company                             location
# 0                               Capgemini         Mississauga, Ontario, Canada
# 1                              Scotiabank             Toronto, Ontario, Canada
# 2    Volkswagen Financial Services Canada           Pickering, Ontario, Canada
# 3                              Scotiabank             Toronto, Ontario, Canada
# 4                              Brookfield             Toronto, Ontario, Canada
# ..                                    ...                                  ...
# 175                    CyberSolve IT Inc.             Toronto, Ontario, Canada
# 176             Southampton Financial Inc             Toronto, Ontario, Canada
# 177                    Raymond James Ltd.             Toronto, Ontario, Canada
# 178                                Amazon  Vancouver, British Columbia, Canada
# 179                                Amazon             Toronto, Ontario, Canada
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Bonus Challenge
#
# Allow your function to also retrieve the "Seniority Level" of each job searched. Note that the Seniority Level info is not in the initial search results. You need to make a separate search request for each job card based on the `currentJobId` value which you can extract from the job card HTML.
#
# After you obtain the Seniority Level info, update the function and add it to a new column of the returned dataframe.

# %%
import re
import time

def scrape_linkedin_job_search_pages_countries_days_seniorities(keywords, pages, country, num_days):
    listing_count = 0
    titles = []
    companies = []
    locations = []
    seniorities = []

    BASE_URL = 'https://www.linkedin.com/jobs/search/?'

    # Convert num_days to seconds for LinkedIn param f_TPR
    seconds = num_days * 86400
    country_param = f'location={country}&' if country else ''

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/117.0",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        "Referer": "https://www.google.com/"
    }

    for _ in range(pages):
        scrape_url = (f"{BASE_URL}"
                      f"keywords={keywords}&"
                      f"{country_param}"
                      f"f_TPR=r{seconds}&"
                      f"start={listing_count}")

        page = requests.get(scrape_url, headers=headers)
        soup = BeautifulSoup(page.text, 'html.parser')

        results = soup.select('ul.jobs-search__results-list')
        if not results:
            break  # No results on this page, stop early
        results = results[0]

        cards = results.select("li")
        if not cards:
            break  # No job cards found, stop early

        for card in cards:
            job_link = card.find("a", href=True)
            if not job_link:
                continue

            job_url = job_link["href"]
            job_id_match = re.search(r'-at-[^-/]+-(\d+)', job_url)
            if not job_id_match:
                continue
            job_id = job_id_match.group(1)
            job_detail_url = f"https://www.linkedin.com/jobs/view/{job_id}"

            title_tag = card.select_one("h3.base-search-card__title")
            company_tag = card.select_one("h4.base-search-card__subtitle")
            location_tag = card.select_one("span.job-search-card__location")

            if not (title_tag and company_tag and location_tag):
                continue

            title = title_tag.get_text(strip=True)
            company = company_tag.get_text(strip=True)
            location = location_tag.get_text(strip=True)

            job_detail_page = requests.get(job_detail_url, headers=headers)
            job_soup = BeautifulSoup(job_detail_page.text, 'html.parser')

            seniority = "Not Listed"
            for li in job_soup.select("li"):
                if 'Seniority level' in li.get_text():
                    seniority = li.get_text(strip=True).replace('Seniority level', '').strip()
                    break

            titles.append(title)
            companies.append(company)
            locations.append(location)
            seniorities.append(seniority)

            listing_count += 1
            time.sleep(0.5)  # be polite

    data = pd.DataFrame({
        "title": titles,
        "company": companies,
        "location": locations,
        "seniority": seniorities
    })

    return data

# %%
results = scrape_linkedin_job_search_pages_countries_days_seniorities('data%20analyst', 2, 'Canada', 3)
results
# Out:
#                                                title         company  \
# 0                                       Data Analyst             MRM
# 1           (Canada) Sr. Data Analyst, Life Sciences  PointClickCare
# 2                                Senior Data Analyst            KOHO
# 3                   Intern, Data Science (Fall 2025)    Wealthsimple
# 4            Senior Data Analyst (Remote - Anywhere)       Jobgether
# 5                                       Data Analyst     Provident10
# 6     Senior Data Analyst - Data Products & Insights             RBC
# 7                                Data Centre Analyst       TransLink
# 8                                Senior Data Analyst         Scopely
# 9                           Business Systems Analyst      Scotiabank
# 10                                     Data Engineer          Indigo
# 11                                      Data Analyst         Valence
# 12                                   Data Analyst II          Intact
# 13              Data Analyst (0 Experience Required)        Peroptyx
# 14                   Business Systems Analyst - Data             RBC
# 15                                   Data Analyst II          Intact
# 16              Data Analyst (0 Experience Required)        Peroptyx
# 17          Data Enablement Analyst- Credit Strategy             RBC
# 18                               Senior Data Analyst           Float
# 19                              Data Analyst Manager          Kaseya
# 20                   Product Operations/Data Analyst          AMISEQ
# 21              Data Analyst (0 Experience Required)        Peroptyx
# 22                      Data Engineer, Risk & Claims            Lyft
# 23  Intern, Data Management and Analysis (Fall 2025)      Bombardier
# 24              Data Analyst (0 Experience Required)        Peroptyx
# 25                                 Reporting Analyst            BGIS
# 26                               Senior Data Analyst          CARFAX
# 27                             Staff Product Analyst      HelloFresh
# 28  Data Analyst (Capital Market, Wealth Management)          Galent
# 29             Data Science Analyst 3, Buyer Success            eBay
# 30                                      Data Analyst             MRM
# 31          (Canada) Sr. Data Analyst, Life Sciences  PointClickCare
# 32                               Senior Data Analyst            KOHO
# 33                  Intern, Data Science (Fall 2025)    Wealthsimple
# 34           Senior Data Analyst (Remote - Anywhere)       Jobgether
# 35                                      Data Analyst     Provident10
# 36    Senior Data Analyst - Data Products & Insights             RBC
# 37                               Data Centre Analyst       TransLink
# 38                   Business Systems Analyst - Data             RBC
# 39                               Senior Data Analyst         Scopely
# 40                          Business Systems Analyst      Scotiabank
# 41                                     Data Engineer          Indigo
# 42                                      Data Analyst         Valence
# 43                                   Data Analyst II          Intact
# 44              Data Analyst (0 Experience Required)        Peroptyx
# 45                                   Data Analyst II          Intact
# 46              Data Analyst (0 Experience Required)        Peroptyx
# 47                               Senior Data Analyst           Float
# 48                              Data Analyst Manager          Kaseya
# 49                   Product Operations/Data Analyst          AMISEQ
# 50              Data Analyst (0 Experience Required)        Peroptyx
# 51                      Data Engineer, Risk & Claims            Lyft
# 52  Intern, Data Management and Analysis (Fall 2025)      Bombardier
# 53              Data Analyst (0 Experience Required)        Peroptyx
# 54                                 Reporting Analyst            BGIS
# 55                               Senior Data Analyst          CARFAX
# 56                             Staff Product Analyst      HelloFresh
# 57  Data Analyst (Capital Market, Wealth Management)          Galent
# 58             Data Science Analyst 3, Buyer Success            eBay
#
#                                         location         seniority
# 0                       Toronto, Ontario, Canada  Mid-Senior level
# 1                   Mississauga, Ontario, Canada  Mid-Senior level
# 2                                         Canada  Mid-Senior level
# 3                       Toronto, Ontario, Canada    Not Applicable
# 4                                         Canada  Mid-Senior level
# 5   St John’s, Newfoundland and Labrador, Canada         Associate
# 6                       Toronto, Ontario, Canada    Not Applicable
# 7            Vancouver, British Columbia, Canada  Mid-Senior level
# 8                                         Canada  Mid-Senior level
# 9                       Toronto, Ontario, Canada  Mid-Senior level
# 10                      Toronto, Ontario, Canada         Associate
# 11                      Toronto, Ontario, Canada         Associate
# 12                     Edmonton, Alberta, Canada  Mid-Senior level
# 13                      Toronto, Ontario, Canada       Entry level
# 14                      Toronto, Ontario, Canada    Not Applicable
# 15                      Calgary, Alberta, Canada  Mid-Senior level
# 16                                        Canada       Entry level
# 17                      Toronto, Ontario, Canada    Not Applicable
# 18                      Toronto, Ontario, Canada  Mid-Senior level
# 19                      Toronto, Ontario, Canada  Mid-Senior level
# 20                      Toronto, Ontario, Canada  Mid-Senior level
# 21                      Calgary, Alberta, Canada       Entry level
# 22                      Toronto, Ontario, Canada  Mid-Senior level
# 23                        Dorval, Quebec, Canada        Internship
# 24           Vancouver, British Columbia, Canada       Entry level
# 25                  Halifax, Nova Scotia, Canada       Entry level
# 26                       London, Ontario, Canada  Mid-Senior level
# 27                      Toronto, Ontario, Canada  Mid-Senior level
# 28                      Toronto, Ontario, Canada  Mid-Senior level
# 29                      Toronto, Ontario, Canada  Mid-Senior level
# 30                      Toronto, Ontario, Canada  Mid-Senior level
# 31                  Mississauga, Ontario, Canada  Mid-Senior level
# 32                                        Canada  Mid-Senior level
# 33                      Toronto, Ontario, Canada    Not Applicable
# 34                                        Canada  Mid-Senior level
# 35  St John’s, Newfoundland and Labrador, Canada         Associate
# 36                      Toronto, Ontario, Canada    Not Applicable
# 37           Vancouver, British Columbia, Canada  Mid-Senior level
# 38                      Toronto, Ontario, Canada    Not Applicable
# 39                                        Canada  Mid-Senior level
# 40                      Toronto, Ontario, Canada  Mid-Senior level
# 41                      Toronto, Ontario, Canada         Associate
# 42                      Toronto, Ontario, Canada         Associate
# 43                     Edmonton, Alberta, Canada  Mid-Senior level
# 44                      Toronto, Ontario, Canada       Entry level
# 45                      Calgary, Alberta, Canada  Mid-Senior level
# 46                                        Canada       Entry level
# 47                      Toronto, Ontario, Canada  Mid-Senior level
# 48                      Toronto, Ontario, Canada  Mid-Senior level
# 49                      Toronto, Ontario, Canada  Mid-Senior level
# 50                      Calgary, Alberta, Canada       Entry level
# 51                      Toronto, Ontario, Canada  Mid-Senior level
# 52                        Dorval, Quebec, Canada        Internship
# 53           Vancouver, British Columbia, Canada       Entry level
# 54                  Halifax, Nova Scotia, Canada       Entry level
# 55                       London, Ontario, Canada  Mid-Senior level
# 56                      Toronto, Ontario, Canada  Mid-Senior level
# 57                      Toronto, Ontario, Canada  Mid-Senior level
# 58                      Toronto, Ontario, Canada  Mid-Senior level
